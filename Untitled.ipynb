# %%
import numpy as np
import scipy
import h5py
import mofapy2
from mofa_subtypes.entry_point import entry_point_subtypes

print("Imports OK")
# Out:
# Imports OK

# %%
print("Imports OK")
# Out:
# Imports OK

# %%
import numpy as np
from mofa_subtypes.entry_point import entry_point_subtypes

rng = np.random.default_rng(0)
N = 30

X1 = rng.normal(size=(N, 15))
X2 = rng.normal(size=(N, 10))

# IMPORTANT: list of views, each view is a list of groups
data = [
    [X1],   # view 1, group 1
    [X2],   # view 2, group 1
]

ep = entry_point_subtypes()
ep.set_data_matrix(data, views_names=["v1","v2"], groups_names=["g1"])
ep.set_model_options(factors=3, likelihoods=["gaussian", "gaussian"])
ep.set_train_options(iter=20, verbose=True)

ep.set_subtypes_options(C=4)

ep.build()
ep.run()
ep.save("smoke_model.hdf5")
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='v1' group='g1' with N=30 samples and D=15 features...
# Successfully loaded view='v2' group='g1' with N=30 samples and D=10 features...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 18
#      16 ep = entry_point_subtypes()
#      17 ep.set_data_matrix(data, views_names=["v1","v2"], groups_names=["g1"])
# ---> 18 ep.set_model_options(factors=3, likelihoods=["gaussian", "gaussian"])
#      19 ep.set_train_options(iter=20, verbose=True)
#      21 ep.set_subtypes_options(C=4)
#
# TypeError: entry_point.set_model_options() got an unexpected keyword argument 'likelihoods'

# %%
import numpy as np
from mofa_subtypes.entry_point import entry_point_subtypes

rng = np.random.default_rng(0)
N = 30
X1 = rng.normal(size=(N, 15))
X2 = rng.normal(size=(N, 10))

data = [
    [X1],  # view 1, group 1
    [X2],  # view 2, group 1
]

ep = entry_point_subtypes()

# likelihoods goes HERE in mofapy2
ep.set_data_matrix(
    data,
    likelihoods=["gaussian", "gaussian"],
    views_names=["v1", "v2"],
    groups_names=["g1"],
)

# model options: no likelihoods kwarg
ep.set_model_options(factors=3)

ep.set_train_options(iter=20, verbose=True)

ep.set_subtypes_options(C=4)

ep.build()
ep.run()
ep.save("smoke_model.hdf5")
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='v1' group='g1' with N=30 samples and D=15 features...
# Successfully loaded view='v2' group='g1' with N=30 samples and D=10 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (v1): gaussian
# - View 1 (v2): gaussian
#
#
# Convergence mode: fast
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 32
#      29 ep.set_subtypes_options(C=4)
#      31 ep.build()
# ---> 32 ep.run()
#      33 ep.save("smoke_model.hdf5")
#
# File /opt/anaconda3/envs/mofa-subtypes/lib/python3.10/site-packages/mofapy2/run/entry_point.py:26, in keyboardinterrupt_saver.<locals>.saver(self, *args, **kwargs)
#      23 @wraps(func)
#      24 def saver(self, *args, **kwargs):
#      25     try:
# ---> 26         func(self, *args, **kwargs)
#      27     # Internal methods will raise TypeError when interrupted
#      28     except (KeyboardInterrupt, TypeError):
#
# File /opt/anaconda3/envs/mofa-subtypes/lib/python3.10/site-packages/mofapy2/run/entry_point.py:1389, in entry_point.run(self)
#    1387 # Fetch training schedule (order of updates for the different nodes)
#    1388 if "schedule" in self.train_opts:
# -> 1389     assert set(self.train_opts["schedule"]) == set(
#    1390         list(self.model.getNodes().keys())
#    1391     ), "Some nodes defined in the training schedule are not present in the model, or viceversa"
#    1392 else:
#    1393     self.train_opts["schedule"] = self.model_builder.schedule
#
# AssertionError: Some nodes defined in the training schedule are not present in the model, or viceversa

# %%
import inspect
print(inspect.signature(ep.set_data_matrix))
print(inspect.signature(ep.set_model_options))
# Out:
# (data, likelihoods=None, views_names=None, groups_names=None, samples_names=None, features_names=None)
# (factors=10, spikeslab_factors=False, spikeslab_weights=True, ard_factors=False, ard_weights=True)

# %%
ep.build()

nodes = list(ep.model.getNodes().keys())
base  = ep.train_opts.get("schedule", [])

# keep base order where possible, then append any missing nodes
schedule = [n for n in base if n in nodes] + [n for n in nodes if n not in base]
ep.train_opts["schedule"] = schedule

ep.run()
# Out:
# ######################################
# ## Training the model with seed 597405 ##
# ######################################
#
#
# ELBO before training:
# Z=-405.43  W=-96.65  Tau=-133.46  Y=-2678.77  AlphaW=-183.95  ThetaW=0.00  C=-25.91  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# Total: -3524.17
#
# Iteration 1: time=0.00, ELBO=-1921.83, deltaELBO=1602.348 (45.46732312%), Factors=3
# - ELBO decomposition:  Z=-401.50  W=-68.04  Tau=-170.98  Y=-1069.47  AlphaW=-190.17  ThetaW=0.00  C=-21.67  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 33.7%
# - Variance explained:  View 0: 13.82%   View 1: 9.00%
# - Fraction of zero weights:  View 0: 4%   View 1: 10%
# - Maximum correlation between factors: 0.04
# - Factor norms:  2.71 1.55 1.48
# - Tau per view (average):  View 0: 1.05   View 1: 1.05
#
#
# Iteration 2: time=0.00, ELBO=-1863.14, deltaELBO=58.682 (1.66511859%), Factors=3
# - ELBO decomposition:  Z=-386.20  W=-77.08  Tau=-170.98  Y=-1034.52  AlphaW=-190.17  ThetaW=0.00  C=-4.19  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 37.4%
# - Variance explained:  View 0: 9.04%   View 1: 4.96%
# - Fraction of zero weights:  View 0: 7%   View 1: 20%
# - Maximum correlation between factors: 0.48
# - Factor norms:  2.46 0.48 0.44
# - Tau per view (average):  View 0: 1.16   View 1: 1.15
#
#
# Iteration 3: time=0.00, ELBO=-1839.28, deltaELBO=23.865 (0.67717908%), Factors=3
# - ELBO decomposition:  Z=-367.89  W=-75.53  Tau=-170.98  Y=-1032.75  AlphaW=-190.17  ThetaW=0.00  C=-1.96  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 40.2%
# - Variance explained:  View 0: 8.33%   View 1: 5.02%
# - Fraction of zero weights:  View 0: 18%   View 1: 23%
# - Maximum correlation between factors: 0.56
# - Factor norms:  2.18 0.05 0.04
# - Tau per view (average):  View 0: 1.16   View 1: 1.16
#
#
# Iteration 4: time=0.00, ELBO=-1815.41, deltaELBO=23.869 (0.67729106%), Factors=3
# - ELBO decomposition:  Z=-348.10  W=-74.02  Tau=-170.98  Y=-1030.63  AlphaW=-190.17  ThetaW=0.00  C=-1.50  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 41.0%
# - Variance explained:  View 0: 8.44%   View 1: 5.83%
# - Fraction of zero weights:  View 0: 27%   View 1: 40%
# - Maximum correlation between factors: 0.57
# - Factor norms:  1.95 0.00 0.00
# - Tau per view (average):  View 0: 1.17   View 1: 1.18
#
#
# Iteration 5: time=0.00, ELBO=-1792.93, deltaELBO=22.480 (0.63788759%), Factors=3
# - ELBO decomposition:  Z=-328.79  W=-72.28  Tau=-170.98  Y=-1029.32  AlphaW=-190.17  ThetaW=0.00  C=-1.39  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 41.1%
# - Variance explained:  View 0: 8.64%   View 1: 6.60%
# - Fraction of zero weights:  View 0: 56%   View 1: 57%
# - Maximum correlation between factors: 0.56
# - Factor norms:  1.74 0.00 0.00
# - Tau per view (average):  View 0: 1.17   View 1: 1.19
#
#
# Iteration 6: time=0.00, ELBO=-1771.44, deltaELBO=21.488 (0.60972224%), Factors=3
# - ELBO decomposition:  Z=-310.35  W=-70.18  Tau=-170.98  Y=-1028.39  AlphaW=-190.17  ThetaW=0.00  C=-1.36  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 41.3%
# - Variance explained:  View 0: 8.86%   View 1: 7.29%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.54
# - Factor norms:  1.55 0.00 0.00
# - Tau per view (average):  View 0: 1.17   View 1: 1.20
#
#
# Iteration 7: time=0.00, ELBO=-1751.00, deltaELBO=20.438 (0.57994417%), Factors=3
# - ELBO decomposition:  Z=-293.01  W=-67.76  Tau=-170.98  Y=-1027.72  AlphaW=-190.17  ThetaW=0.00  C=-1.36  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 36.5%
# - Variance explained:  View 0: 9.05%   View 1: 7.89%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.51
# - Factor norms:  1.37 0.00 0.00
# - Tau per view (average):  View 0: 1.17   View 1: 1.20
#
#
# Iteration 8: time=0.00, ELBO=-1731.87, deltaELBO=19.135 (0.54296874%), Factors=3
# - ELBO decomposition:  Z=-277.00  W=-65.06  Tau=-170.98  Y=-1027.30  AlphaW=-190.17  ThetaW=0.00  C=-1.36  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 45.1%
# - Variance explained:  View 0: 9.21%   View 1: 8.41%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.50
# - Factor norms:  1.22 0.00 0.00
# - Tau per view (average):  View 0: 1.17   View 1: 1.21
#
#
# Iteration 9: time=0.00, ELBO=-1714.36, deltaELBO=17.511 (0.49688569%), Factors=3
# - ELBO decomposition:  Z=-262.51  W=-62.17  Tau=-170.98  Y=-1027.15  AlphaW=-190.17  ThetaW=0.00  C=-1.38  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 39.2%
# - Variance explained:  View 0: 9.28%   View 1: 8.81%
# - Fraction of zero weights:  View 0: 67%   View 1: 70%
# - Maximum correlation between factors: 0.49
# - Factor norms:  1.10 0.00 0.00
# - Tau per view (average):  View 0: 1.17   View 1: 1.21
#
#
# Iteration 10: time=0.00, ELBO=-1698.65, deltaELBO=15.712 (0.44584368%), Factors=3
# - ELBO decomposition:  Z=-249.66  W=-59.13  Tau=-170.98  Y=-1027.31  AlphaW=-190.17  ThetaW=0.00  C=-1.39  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 47.1%
# - Variance explained:  View 0: 9.26%   View 1: 9.09%
# - Fraction of zero weights:  View 0: 67%   View 1: 70%
# - Maximum correlation between factors: 0.49
# - Factor norms:  1.01 0.00 0.00
# - Tau per view (average):  View 0: 1.17   View 1: 1.21
#
#
# Iteration 11: time=0.00, ELBO=-1684.67, deltaELBO=13.976 (0.39658109%), Factors=3
# - ELBO decomposition:  Z=-238.43  W=-55.99  Tau=-170.98  Y=-1027.70  AlphaW=-190.17  ThetaW=0.00  C=-1.40  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 35.1%
# - Variance explained:  View 0: 9.13%   View 1: 9.27%
# - Fraction of zero weights:  View 0: 67%   View 1: 70%
# - Maximum correlation between factors: 0.51
# - Factor norms:  0.94 0.00 0.00
# - Tau per view (average):  View 0: 1.17   View 1: 1.21
#
#
# Iteration 12: time=0.00, ELBO=-1672.33, deltaELBO=12.340 (0.35014780%), Factors=3
# - ELBO decomposition:  Z=-228.84  W=-52.80  Tau=-170.98  Y=-1028.14  AlphaW=-190.17  ThetaW=0.00  C=-1.39  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 40.4%
# - Variance explained:  View 0: 8.93%   View 1: 9.40%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.53
# - Factor norms:  0.89 0.00 0.00
# - Tau per view (average):  View 0: 1.16   View 1: 1.21
#
#
# Iteration 13: time=0.00, ELBO=-1661.70, deltaELBO=10.632 (0.30168014%), Factors=3
# - ELBO decomposition:  Z=-220.93  W=-49.77  Tau=-170.98  Y=-1028.47  AlphaW=-190.17  ThetaW=0.00  C=-1.38  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 40.3%
# - Variance explained:  View 0: 8.69%   View 1: 9.52%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.57
# - Factor norms:  0.85 0.00 0.00
# - Tau per view (average):  View 0: 1.16   View 1: 1.22
#
#
# Iteration 14: time=0.00, ELBO=-1652.92, deltaELBO=8.774 (0.24896752%), Factors=3
# - ELBO decomposition:  Z=-214.72  W=-47.16  Tau=-170.98  Y=-1028.56  AlphaW=-190.17  ThetaW=0.00  C=-1.33  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 40.3%
# - Variance explained:  View 0: 8.44%   View 1: 9.64%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.60
# - Factor norms:  0.82 0.00 0.00
# - Tau per view (average):  View 0: 1.16   View 1: 1.22
#
#
# Iteration 15: time=0.00, ELBO=-1645.99, deltaELBO=6.930 (0.19664029%), Factors=3
# - ELBO decomposition:  Z=-210.06  W=-45.12  Tau=-170.98  Y=-1028.41  AlphaW=-190.17  ThetaW=0.00  C=-1.25  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 42.1%
# - Variance explained:  View 0: 8.20%   View 1: 9.76%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.64
# - Factor norms:  0.79 0.00 0.00
# - Tau per view (average):  View 0: 1.16   View 1: 1.22
#
#
# Iteration 16: time=0.00, ELBO=-1640.78, deltaELBO=5.218 (0.14807511%), Factors=3
# - ELBO decomposition:  Z=-206.74  W=-43.63  Tau=-170.98  Y=-1028.11  AlphaW=-190.17  ThetaW=0.00  C=-1.14  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 38.6%
# - Variance explained:  View 0: 7.98%   View 1: 9.89%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.66
# - Factor norms:  0.77 0.00 0.00
# - Tau per view (average):  View 0: 1.16   View 1: 1.22
#
#
# Iteration 17: time=0.00, ELBO=-1637.19, deltaELBO=3.582 (0.10163310%), Factors=3
# - ELBO decomposition:  Z=-204.69  W=-42.58  Tau=-170.98  Y=-1027.74  AlphaW=-190.17  ThetaW=0.00  C=-1.04  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 38.5%
# - Variance explained:  View 0: 7.78%   View 1: 10.02%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.67
# - Factor norms:  0.76 0.00 0.00
# - Tau per view (average):  View 0: 1.16   View 1: 1.22
#
#
# Iteration 18: time=0.00, ELBO=-1635.03, deltaELBO=2.162 (0.06133836%), Factors=3
# - ELBO decomposition:  Z=-203.71  W=-41.82  Tau=-170.98  Y=-1027.37  AlphaW=-190.17  ThetaW=0.00  C=-0.98  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 37.4%
# - Variance explained:  View 0: 7.60%   View 1: 10.14%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.66
# - Factor norms:  0.75 0.00 0.00
# - Tau per view (average):  View 0: 1.16   View 1: 1.23
#
#
# Iteration 19: time=0.00, ELBO=-1633.92, deltaELBO=1.117 (0.03169798%), Factors=3
# - ELBO decomposition:  Z=-203.52  W=-41.27  Tau=-170.98  Y=-1027.03  AlphaW=-190.17  ThetaW=0.00  C=-0.93  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 34.8%
# - Variance explained:  View 0: 7.43%   View 1: 10.25%
# - Fraction of zero weights:  View 0: 67%   View 1: 67%
# - Maximum correlation between factors: 0.80
# - Factor norms:  0.75 0.00 0.00
# - Tau per view (average):  View 0: 1.17   View 1: 1.23
#
#
#
#
# #######################
# ## Training finished ##
# #######################

# %%
ep.set_subtypes_options(C=4)
ep.set_train_options(iter=20, verbose=True)
ep.build()

ep.train_opts["schedule"] = list(ep.model.getNodes().keys())
ep.run()
# Out:
# Convergence mode: fast
#
#
#
# ######################################
# ## Training the model with seed 601747 ##
# ######################################
#
#
# ELBO before training:
# Z=-362.31  W=-96.65  Tau=-133.46  Y=-2678.77  AlphaW=-183.95  ThetaW=0.00  C=-25.91  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# Total: -3481.06
#
# Iteration 1: time=0.00, ELBO=-1454.05, deltaELBO=2027.004 (58.22955103%), Factors=3
# - ELBO decomposition:  Z=-1.88  W=-35.69  Tau=-170.98  Y=-1054.16  AlphaW=-190.17  ThetaW=0.00  C=-1.17  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 35.3%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.12
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.10   View 1: 1.11
#
#
# Iteration 2: time=0.00, ELBO=-1506.80, deltaELBO=-52.751 (1.51537722%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-49.66  W=-40.71  Tau=-170.98  Y=-1054.17  AlphaW=-190.17  ThetaW=0.00  C=-1.11  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 43.5%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.18
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.11   View 1: 1.11
#
#
# Iteration 3: time=0.00, ELBO=-1534.65, deltaELBO=-27.850 (0.80003033%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-76.80  W=-41.54  Tau=-170.98  Y=-1054.24  AlphaW=-190.17  ThetaW=0.00  C=-0.92  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 46.1%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.13
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.10   View 1: 1.11
#
#
# Iteration 4: time=0.00, ELBO=-1546.40, deltaELBO=-11.744 (0.33737261%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-89.79  W=-40.60  Tau=-170.98  Y=-1054.16  AlphaW=-190.17  ThetaW=0.00  C=-0.70  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 39.6%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.18
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.11   View 1: 1.11
#
#
# Iteration 5: time=0.00, ELBO=-1550.09, deltaELBO=-3.690 (0.10601123%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-95.73  W=-38.86  Tau=-170.98  Y=-1053.92  AlphaW=-190.17  ThetaW=0.00  C=-0.42  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 39.6%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.21
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.11   View 1: 1.11
#
#
# Iteration 6: time=0.00, ELBO=-1552.11, deltaELBO=-2.023 (0.05810672%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-100.05  W=-37.02  Tau=-170.98  Y=-1053.54  AlphaW=-190.17  ThetaW=0.00  C=-0.35  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 40.5%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.27
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.11   View 1: 1.11
#
#
# Iteration 7: time=0.00, ELBO=-1554.05, deltaELBO=-1.937 (0.05563502%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-104.12  W=-35.40  Tau=-170.98  Y=-1053.07  AlphaW=-190.17  ThetaW=0.00  C=-0.31  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 36.3%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.20
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.11   View 1: 1.11
#
#
# Iteration 8: time=0.00, ELBO=-1556.27, deltaELBO=-2.221 (0.06381167%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-108.22  W=-34.07  Tau=-170.98  Y=-1052.56  AlphaW=-190.17  ThetaW=0.00  C=-0.28  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 40.1%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.21
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.11   View 1: 1.11
#
#
# Iteration 9: time=0.00, ELBO=-1558.88, deltaELBO=-2.612 (0.07504477%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-112.44  W=-32.98  Tau=-170.98  Y=-1052.05  AlphaW=-190.17  ThetaW=0.00  C=-0.26  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 39.1%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.23
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.11   View 1: 1.11
#
#
# Iteration 10: time=0.00, ELBO=-1561.86, deltaELBO=-2.977 (0.08551956%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-116.79  W=-32.11  Tau=-170.98  Y=-1051.56  AlphaW=-190.17  ThetaW=0.00  C=-0.24  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 38.5%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.23
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.11   View 1: 1.11
#
#
# Iteration 11: time=0.00, ELBO=-1565.11, deltaELBO=-3.255 (0.09351352%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-121.20  W=-31.40  Tau=-170.98  Y=-1051.12  AlphaW=-190.17  ThetaW=0.00  C=-0.23  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 49.1%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.28
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.11   View 1: 1.12
#
#
# Iteration 12: time=0.00, ELBO=-1568.55, deltaELBO=-3.434 (0.09864283%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-125.62  W=-30.83  Tau=-170.98  Y=-1050.71  AlphaW=-190.17  ThetaW=0.00  C=-0.23  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 43.0%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.18
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.11   View 1: 1.12
#
#
# Iteration 13: time=0.00, ELBO=-1572.07, deltaELBO=-3.523 (0.10120626%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-129.99  W=-30.36  Tau=-170.98  Y=-1050.35  AlphaW=-190.17  ThetaW=0.00  C=-0.22  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 40.0%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.29
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.12   View 1: 1.12
#
#
# Iteration 14: time=0.00, ELBO=-1575.61, deltaELBO=-3.542 (0.10173939%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-134.26  W=-29.96  Tau=-170.98  Y=-1050.02  AlphaW=-190.17  ThetaW=0.00  C=-0.22  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 41.2%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.46
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.12   View 1: 1.12
#
#
# Iteration 15: time=0.00, ELBO=-1579.12, deltaELBO=-3.508 (0.10078402%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-138.40  W=-29.63  Tau=-170.98  Y=-1049.72  AlphaW=-190.17  ThetaW=0.00  C=-0.22  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 44.0%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.35
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.12   View 1: 1.12
#
#
# Iteration 16: time=0.00, ELBO=-1582.56, deltaELBO=-3.439 (0.09879757%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-142.40  W=-29.34  Tau=-170.98  Y=-1049.45  AlphaW=-190.17  ThetaW=0.00  C=-0.21  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 35.3%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.43
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.12   View 1: 1.12
#
#
# Iteration 17: time=0.00, ELBO=-1585.91, deltaELBO=-3.346 (0.09613395%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-146.24  W=-29.09  Tau=-170.98  Y=-1049.21  AlphaW=-190.17  ThetaW=0.00  C=-0.21  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 33.2%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.16
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.12   View 1: 1.12
#
#
# Iteration 18: time=0.00, ELBO=-1589.15, deltaELBO=-3.239 (0.09305375%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-149.92  W=-28.88  Tau=-170.98  Y=-1048.98  AlphaW=-190.17  ThetaW=0.00  C=-0.21  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 41.4%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.43
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.12   View 1: 1.12
#
#
# Iteration 19: time=0.00, ELBO=-1592.27, deltaELBO=-3.124 (0.08974287%), Factors=3
# Warning, lower bound is decreasing...
# - ELBO decomposition:  Z=-153.43  W=-28.69  Tau=-170.98  Y=-1048.78  AlphaW=-190.17  ThetaW=0.00  C=-0.21  Gamma=0.00  V=0.00  MuLambda=0.00  m0=0.00  t0=0.00  MuZ=0.00  AlphaZ=0.00
# - Time spent in ELBO computation: 52.0%
# - Variance explained:  View 0: 0.00%   View 1: 0.00%
# - Fraction of zero weights:  View 0: 100%   View 1: 100%
# - Maximum correlation between factors: 0.24
# - Factor norms:  0.00 0.00 0.00
# - Tau per view (average):  View 0: 1.12   View 1: 1.12
#
#
#
#
# #######################
# ## Training finished ##
# #######################

# %%
ep.build()

nodes = list(ep.model.getNodes().keys())
sched = ep.train_opts.get("schedule", [])

nodes_set = set(nodes)
sched_set = set(sched)

print("N nodes:", len(nodes))
print("N sched:", len(sched))

print("Missing in schedule (in model, not in schedule):", sorted(nodes_set - sched_set))
print("Extra in schedule (in schedule, not in model):", sorted(sched_set - nodes_set))
# Out:
# N nodes: 14
# N sched: 14
# Missing in schedule (in model, not in schedule): []
# Extra in schedule (in schedule, not in model): []

# %%
import numpy as np
import h5py
from mofa_su:contentReference[oaicite:9]{index=9}port entry_point_subtypes

rng = np.random.default_rng(0)

# Synthetic data with 2 latent-space subtypes
N, K, D = 80, 3, 50
C_true = 2
c = rng.integers(C_true, size=N)
mu = np.array([[-2, 0, 2],
               [ 2, 0,-2]], dtype=float)
Z = rng.normal(loc=mu[c], scale=1.0, size=(N, K))
W = rng.normal(0, 1, size=(D, K))
Y = Z @ W.T + rng.normal(0, 0.5, size=(N, D))

data = [Y]  # mofapy2 expects a list of views

ep = entry_point_subtypes()
ep.set_data_matrix(data)
ep.set_model_options(factors=K, likelihoods=["gaussian"])
ep.set_train_options(iter=50, verbose=True, seed=0)
ep.set_subtypes_options(C=4)  # truncation
ep.build()
ep.run()
ep.save("smoke_mofa_subtypes.hdf5")

with h5py.File("smoke_mofa_subtypes.hdf5", "r") as f:
    R = f["subtypes/responsibilities"][...]
print("R shape:", R.shape)
print("row sums (should be 1):", R.sum(axis=1)[:5])
print("mean max-resp:", R.max(axis=1).mean())
# Out:
#   Cell In[10], line 3
#     from mofa_su:contentReference[oaicite:9]{index=9}port entry_point_subtypes
#                 ^
# SyntaxError: invalid syntax
